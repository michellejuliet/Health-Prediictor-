# %% [markdown]
# <a href="https://colab.research.google.com/github/michellejuliet/Health-Prediictor-/blob/main/Group_work_Data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data analysis on CardioVascular Data set

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path='/content/drive/MyDrive/Colab Notebooks/cardio_train.csv'
cardio_data=pd.read_csv(path, sep=';')
cardio_data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
print(cardio_data.shape)  # checks the no. of columns and rows
print(cardio_data.info())  # check data types and columns with missing values
# Out:
# (70000, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB
# None

# %% [markdown]
# Gender:
#
# 1 - Female
# 2 - Male

# %%
# convert age from days to years
cardio_data['age'] = cardio_data['age'] // 365
# cardio_data['age'] = (cardio_data['age'] / 365).astype(int)
# cardio_data["age"] = cardio_data["age"].map(lambda x: x // 365)
cardio_data.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2     168    62.0    110     80            1     1      0
# 1   1   55       1     156    85.0    140     90            3     1      0
# 2   2   51       1     165    64.0    130     70            3     1      0
# 3   3   48       2     169    82.0    150    100            1     1      0
# 4   4   47       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# check for unique values
cardio_data.nunique()
# Out:
# id             70000
# age               28
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64

# %% [markdown]
# Categorical data:
# 1. Cholestrol
# 2. Glucose
# 3. Smoke
# 4. alcohol
# 5. Ative
# 6. Gender
#
# Continuos data:
# 1. age
# 2. height
# 3. weight
# 4. ap_hi
# 5. ap_lo

# %%
# For categorical columns, use df['column_name'].value_counts()
print(cardio_data['cholesterol'].value_counts())

print(cardio_data['gluc'].value_counts())
print(cardio_data['smoke'].value_counts())
print(cardio_data['alco'].value_counts())
print(cardio_data['active'].value_counts())
print(cardio_data['gender'].value_counts())

# %%
cardio_data.describe()

# %%
plt.figure(figsize=(5, 3))
plt.hist(cardio_data['age'], bins=5, edgecolor='black', color='lightblue')

plt.title('Age distribution')
plt.xlabel('Age values')
plt.ylabel('Frequency')
plt.show()

# %%
cardio_data['age'].hist(figsize=(5,4))
# Out:
# <Axes: >
